# %% [markdown]
# ** HOW TO USE PRINT**

# %%
print('hi')
# Out:
# hi

# %%
print("hello world")
# Out:
# hello world

# %%
print("welcome to python Programming")
# Out:
# welcome to python Programming

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
print(5,2)
# Out:
# 5 2

# %% [markdown]
# this is first program

# %%
print(5
print(2)

# %%
  a=5
  b=2
  c=a+b
  print(c)
# Out:
# 7

# %%
print("HELLO")
# Out:
# HELLO

# %%
a=10
b=5
c=a+b
print(c)

# %% [markdown]
# Different Way to use print function in python

# %%
print(a)

# %%
print(b)

# %%
print(a,b)

# %%
print (5*0.6 - 0.5*9.81*0.6**2)

# %%
v0 = 5
g = 9.81
t = 0.6
y = v0*t - 0.5*g*t**2
print (y)
# Out:
# 1.2342

# %%
print("Hello World!!!")
# Out:
# Hello World!!!

# %%
v0 = 5
g = 9.81
t = 0.6
y = v0*t - 0.5*g*t**2
print ('At t=%g s, the height of the ball is %.2f m.' % (t, y))
# Out:
# At t=0.6 s, the height of the ball is 1.23 m.

# %%
v0 = 5
g = 9.81
t = 0.6
y = v0*t - 0.5*g*t**2

print ("""
At t=%f s, a ball with
initial velocity v0=%.4E m/s
is located at the height %.2f m.
""" % (t, v0, y))

# %%
# use of \n
print ( """y(t) is
the position of
our ball.""")
print ('y(t) is\n the position of\n our ball')
# Out:
# y(t) is
# the position of
# our ball.
# y(t) is
#  the position of
#  our ball

# %%
#use of ;
v0 = 3; g = 9.81; t = 0.6
y = v0*t - 0.5*g*t**2
print (y)
#OR
v0=3;g=9.81;t=0.6;y=v0*t-0.5*g*t**2;
print (y)
# Out:
# 0.034199999999999786
# 0.034199999999999786

# %% [markdown]
# **formating**

# %%
x = "Hello World"
print(type(x))
x = 20
print(type(x))
x = 20.5
print(type(x))
x = 1j
print(type(x))
x = ["apple", "banana", "cherry"]
print(type(x))
x = ("apple", "banana", "cherry")
print(type(x))
x = {"name" : "John", "age" : 36}
print(type(x))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>

# %%
x = str("s1")
y = str(2)
z = str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a = " Hello, WHor,ld! "
print(a)
#The strip() method removes any whitespace from the beginning or the ending:
print(a.strip()) # returns "Hello, WHor,ld!"
#a=a.strip()
print(a.lower())
print(a.upper())
print(a.replace("H", "J"))
y= "PYTHON   PROGRAM   INTEGRATED"
print(y.split("   ")) # returns ['PYTHON', ' PROGRAM!']
#The split() method splits the string into substrings if it finds instances of the separator:
a = "PYTHON "
b = "PROGRAM"
c = a+b
print(c)
# Out:
#  Hello, WHor,ld!
# Hello, WHor,ld!
#  hello, whor,ld!
#  HELLO, WHOR,LD!
#  Jello, WJor,ld!
# ['PYTHON', 'PROGRAM', 'INTEGRATED']
# PYTHON PROGRAM

# %%
test_list1=['abcd', 786, 'john' , 70]
tinylist=[123, 'mary']
test_list1= test_list1+tinylist
print(test_list1)
# Out:
# ['abcd', 786, 'john', 70, 123, 'mary']

# %%
#       210987654321    Negative index
str1 = 'Hello World!'
#       012345678901    Positive index
print (str1[-1])
print (str1[-3:-1])
print (str1[-12:])
# Out:
# !
# ld
# Hello World!

# %%
print('This','is','Nirma', sep= ' ', end='.')
# Out:
# This is Nirma.

# %%
a=5;b=2
print('a={0}'.format(a)) #a=5
print('a={0} and b={1}'.format(a, b)) #a=5 and b=2
print('a={1} and b={0}'.format(a, b)) #a=2 and b=5
print('a={} and b={}'.format(a, b))	#a=5 and b=2 #auto field numbering
print('bin={0:b}, oct={0:o}, hex={0:x}'.format(12)) #bin=1100, oct=14, hex=c
print('bin={0:b}, oct={1:o}, hex={1:x}'.format(12,10)) #bin=1100, oct=12, hex=a
print('bin={0:b}, oct={1:o}, hex={0:X}'.format(12,10)) #bin=1100, oct=12, hex=A
# Out:
# a=5
# a=5 and b=2
# a=2 and b=5
# a=5 and b=2
# bin=1100, oct=14, hex=c
# bin=1100, oct=12, hex=a
# bin=1100, oct=12, hex=C

# %%
print('V','S','U', sep=",\t", end='X')
# Out:
# V,	S,	UX

# %%
a=9
b=8
print("a={0:d} and b={1:d}".format(a, b)) 			#a=5 and b=2
print("a={0:3d} and b={1:5d}".format(a, b)) 		#a=  5 and b=    2
print("a={0:>3d} and b={1:>5d}".format(a, b)) 		#a=  5 and b=    2
print("a={0:<3d} and b={1:<5d}".format(a, b))		#a=5   and b=2
print("a={:<{}d} and b={:<{}d}".format(a,3,b,5))		#???
print("a={0:03d} and b={1:05d}".format(a, b)) 		#a=005 and b=00002
print("a={0:^3d} and b={1:^5d}".format(a, b)) 		#a= 5  and b=  2
print("a={:f}".format(123.4567898990)) 				#a=123.456790
print("a={:8.3f}".format(123.4567898)) 			#a= 123.457

# %%
for i in range (2, 6):
        # Using formatters to give 6
        # spaces to each set of values
        print("{:>6d} {:<6d} {:^6d} {:6d}"
        .format(i, i ** 2, i ** 3, i ** 4))

# %%
print("a={:f}".format(123.4567898990)) 			#a=123.456790
print("a={:8.3f}".format(123.4567898)) 			#a= 123.457
# Out:
# a=123.456790
# a= 123.457

# %%
a = """Lorem ipsum dolor sit amet,
consectetur adipiscing elit,
sed do eiusmod tempor incididunt
ut labore et dolore magna aliqua."""
print(a)
# Out:
# Lorem ipsum dolor sit amet,
# consectetur adipiscing elit,
# sed do eiusmod tempor incididunt
# ut labore et dolore magna aliqua.

# %%
# Python docstrings are the string literals that appear right
# after the definition of a function, method, class, or module.
# Let's take an example.
def square(n):
   '''Takes in a number n, returns the square of n'''
   return n**2
print(square(6))
print(square.__doc__)
# Out:
# 36
# Takes in a number n, returns the square of n

# %%
def square(n):
   '''Takes in a number n, returns the square of n'''
   return n**2
print(square.__doc__)
# Out:
# Takes in a number n, returns the square of n

# %%
a = "Hello, World!"
print(a[1])
# Out:
# e

# %%
x = int(1)   # x will be 1
y = int(2.8) # y will be 2
z = int("3") # z will be 3
print(x,y,z)
x = float(1)     # x will be 1.0
y = float(2.8)   # y will be 2.8
z = float("3")   # z will be 3.0
w = float("4.2") # w will be 4.2
print(x,y,z,w)

# %%
x = 15
y = 2
print(x / y)
print(x // y)
# Out:
# 7.5
# 7

# %% [markdown]
# Collecting inputs from user...
#
# It will work ust like scanf() in C

# %%
a=input("Enter a:") # by default input value is string
print(type(a))
print(a)
a=int(input("Enter a:"))
#a = int(a)
print(type(a))
print(a)
# Out:
# Enter a:4
# <class 'str'>
# 4
# Enter a:3
# <class 'int'>
# 3

# %%
input = input("Enter any number of your choice:")   # enter 10 + 10
print(input)
print(type(input))
# Out:
# Enter any number of your choice:10+10
# 10+10
# <class 'str'>

# %%
eval = eval(input("Enter any number of your choice"))
print(eval)
print(type(eval))
# Out:
# Enter any number of your choice10+10
# 20
# <class 'int'>

# %%
evaluate = input("Enter what operation x has to perform: ")
# enter x + x + 100 - 35 + 5 * 80
print(evaluate)
print(type(evaluate))
x = int(input("x"))
print(type(x))
expression = eval(X)
print(expression)
print(type(expression))
# Out:
# Enter what operation x has to perform: X+30
# X+30
# <class 'str'>
# x2
# <class 'int'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-2486193131.py in <cell line: 0>()
#       5 x = int(input("x"))
#       6 print(type(x))
# ----> 7 expression = eval(X)
#       8 print(expression)
#       9 print(type(expression))
#
# NameError: name 'X' is not defined

# %%
a=[10,20]
print(id(a))
print(a[1])
print(id(a[0]))
print(id(a[1]))
a[0]=20
a[1]=30
print("----")
print(id(a[0]))
print(id(a[1]))
# Out:
# 1748806441992
# 20
# 140732906840752
# 140732906841072
# ----
# 140732906841072
# 140732906841392

# %%
#Prompt the user to input a word
word = input("Input a word to reverse: ")

# Iterate through the characters of the word in reverse order
for char in range(len(word) - 1, -1, -1):
    # Print each character from the word in reverse order without a new line (end="")
    print(word[char], end="")

# Print a new line to separate the reversed word from the next output
print("\n")
# Out:
# Input a word to reverse: amit
# tima
