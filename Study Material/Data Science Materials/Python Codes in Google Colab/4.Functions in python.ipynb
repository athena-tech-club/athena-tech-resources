# %% [markdown]
# # This is a lecture note on functions
#     The contents are from the suggested reference books and online sources
#     Funtion :
#             Group of statements intended to perform a particular task
#
#     Types:
#         1) User defined
#         2) Built In
# ![functions.png](attachment:functions.png)

# %% [markdown]
# # Built in function
#
# ![image.png](attachment:image.png)

# %%
#Usage of a built in method
#Importing the module / package

import math
a=math.sqrt(64)
print(a)

# %%
#importing a particular sub function from a package
from math import sin
rad = math.radians(45)
print(rad)
sine_angle=sin(rad)
print('sine of an angle {} degree / radians {} is {}'
      .format(45,rad, sine_angle))

# %% [markdown]
# ## Help facility in python

# %%
#Method to list out all methods of a package

help(math)
# Out:
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     copysign(x, y, /)
# ...

# %%
#Help facililty for a particular method

help(sin)
# Out:
# Help on built-in function sin in module math:
#
# sin(x, /)
#     Return the sine of x (measured in radians).

# %%
#Alternative method

for method in dir(str):
    print(method)
# Out:
# __add__
# __class__
# __contains__
# __delattr__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __getnewargs__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __iter__
# __le__
# __len__
# __lt__
# __mod__
# __mul__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __rmod__
# __rmul__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# capitalize
# casefold
# center
# count
# encode
# endswith
# expandtabs
# find
# format
# format_map
# index
# isalnum
# isalpha
# isascii
# isdecimal
# isdigit
# isidentifier
# islower
# isnumeric
# isprintable
# isspace
# istitle
# isupper
# join
# ljust
# lower
# lstrip
# maketrans
# partition
# removeprefix
# removesuffix
# replace
# rfind
# rindex
# rjust
# rpartition
# rsplit
# rstrip
# split
# splitlines
# startswith
# strip
# swapcase
# title
# translate
# upper
# zfill

# %% [markdown]
# # Installation of a built in package / module
# ![image.png](attachment:image.png)

# %% [markdown]
# # User defined functions
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Function definition
def sum(a,b):
    c=a+b
    return c
#Function call
d=sum(10,20)
print('The sum of {} + {} = {}'.format(10,20,d))
# Out:
# The sum of 10 + 20 = 30

# %%
def mul(a,b):
    result = a*b
    return result
if __name__ =='__main__':
    x = mul(1,2)
    print(x)
# Out:
# 2

# %% [markdown]
# ## Practice question :
# Write a function with accepts required arguments to generate geometric progression of n terms. The function should return sum of n terms generated.
# ( a * (int)(math.pow(r, N - 1)) )

# %%
 #Take user input
 number = 2

# Condition of the while loop
while number < 5 :
    print("Thank you")
    # Increment the value of the variable "number by 1"
    number = number+1
# Out:
# Thank you
# Thank you
# Thank you

# %% [markdown]
# # More on python functions
#  ##   Note: Python’s functions are first-class objects.
#
#    ###     You can assign them to variables,
#    ###      Store them in data structures
#    ###     Pass them as arguments to other functions
#    ###     Even return them as values from other functions

# %% [markdown]
# ## Demonstration of the following with an example
# ### 1) Assign function to a variable
#
# ### 2) Define one function in another
#
# ### 3) Pass one function as parameter in another function
#
# ### 4) Possible that a function can return another function

# %%
#1) Assign function to a variable

def function(text):
    return text.upper() + 'assignment'

print (function('variable ') )

function_to_variable = function

print( function_to_variable('function ') )
# Out:
# VARIABLE assignment
# FUNCTION assignment

# %%
#2) Define one function in another

def calc(a,b):
    print('a = {} b= {}' .format(a,b))

  def addition():
        print('{} + {} = {}'.format(a,b,(a+b)))
    addition()
    return

calc(10,20)
# Out:
# a = 10 b= 20
# 10 + 20 = 30

# %%
#3) Pass one function as parameter in another function
def Function1(text):
    return text.upper()

def Function2(text):
    return text.lower()

def Demo(Another_function):
    # storing the function in a variable
    greeting = Another_function("Demonstration of function passed as an argument")
    print(greeting)

Demo(Function1)
Demo(Function2)
# Out:
# DEMONSTRATION OF FUNCTION PASSED AS AN ARGUMENT
# demonstration of function passed as an argument

# %%
#4) Possible that a function can return another function
def display():
    def message():
        return 'This is a function that returns another function'

    return message

#Call display() which inturn calls message()
#Returing function which is assigned to a variable
Function=display()

#Demonstrating the printing of messages
print(Function())
print(Function)
# Out:
# This is a function that returns another function
# <function display.<locals>.message at 0x7fb57bc14560>

# %% [markdown]
# # Scope and lifetime of variables

# %%
#Scope and lifetime of variables

main_variable=100
def outer_function():
    main_variable=200
    def inner_function():
        main_variable=300
        print('Inner function {}'.format(main_variable))
        return
    inner_function()
    print('Outer function {}' .format(main_variable))
    return
outer_function()
print('Main function {}'.format(main_variable))
# Out:
# Inner function 300
# Outer function 200
# Main function 100

# %% [markdown]
# # Passing Parameters in python
# ### Other programming languages its
#
# ### 1) Pass by value
#
# ### 2) Pass by reference
#
#
# ## However python treats everything as objects and values are passed as object references.

# %% [markdown]
# # Formal and Actual Parameters
# ### 1) Positional arguments
#
# ### 2) Keyword arguments
#
# ### 3) Default arguments
#
# ### 4) Variable length arguments

# %%
# 1) Positional arguments
# 1 - to - 1 mapping of arguments
# Function definition
def multiply(a,b):
    c=a*b
    print(a,b)
    return c
#Function call
x=10
y=20
d=multiply(x,y)
print('The Multiplication of {} X {} = {}'.format(x,y,d))

# %%
#2) Keyword arguments

def item(item,price,x):
    price1 = x*price
    print('The price of {} {}  with per unit price of {}  is {}'.format(x,item,price,price1))

item('book',100,2)
item(price=200,x=20,item='pen')
# Out:
# The price of 2 book  with per unit price of 100  is 200
# The price of 20 pen  with per unit price of 200  is 4000

# %%
#3) Default arguments

def item(item,price,count=3):
    price1 = count*price
    print('The price of {} {}  with per unit price of {}  is {}'.format(count,item,price,price1))

item('book',100,2)
#Count has a default vakue
item(price=200,item='pen')

# %%
#4) Variable length arguments
# *args for variable arguments --> (Non keyword arguments)
#*kwargs for passing keyworded, variable length dictionary
# argument list to the calling function. --> (keyword arguments)


# Format
# def function_name(positional_parameters, *args,*kwargs)

def addition(fargument, *args,**kwargs):
    print('Formal Argument',fargument)
    sum=0
    for i in args:
        print('i= ',i)
        sum += i

    print('sum = ',sum)
    for j in kwargs:
        print(kwargs[j])
print('With positional and *args parameters')
addition(100,20,30)

print('With positional and *args and **kwargs parameters')
addition('addition',10,20,30,sum='addition',multiply='multiply')
# Out:
# With positional and *args parameters
# Formal Argument 100
# i=  20
# i=  30
# sum =  50
# With positional and *args and **kwargs parameters
# Formal Argument addition
# i=  10
# i=  20
# i=  30
# sum =  60
# addition
# multiply

# %% [markdown]
# # Global vs. Local Variables
# Variables that are defined inside a function body have a local scope, and those defined outside have a global scope.
#
# This means that local variables can be accessed only inside the function in which they are declared, whereas global variables can be accessed throughout the program body by all functions.

# %%
# This is a global variable.
total = 0

# Function definition is here
def sum( arg1, arg2 ):
    # Add both the parameters and return them."
    total = arg1 + arg2; # Here total is local variable.
    print ("Inside the function local total : ", total)
    return

# Now you can call sum function
sum(10, 20)
print ("Outside the function global total : ", total )
# Out:
# Inside the function local total :  30
# Outside the function global total :  0

# %%
# This is a global variable.
total = 0

# Function definition is here
def sum( arg1, arg2 ):
   # Add both the parameters and return them."
    global total
    total = arg1 + arg2;
    print ("Inside the function local total : ", total)
    return

# Now you can call sum function
sum( 10, 20 )
print ("Outside the function global total : ", total )
# Out:
# Inside the function local total :  30
# Outside the function global total :  30

# %% [markdown]
# ## Multiple return values
# ### A python function can return multiple values

# %%
# This function returns a tuple
def function():
    str = "Python can return multiple values"
    x   = 100
    return str, x;  # Return tuple, we could also
                    # write (str, x)
#Call the function now
return_str, return_x = function() # Assign returned tuple
print(return_str)
print(return_x)
print( function())

# %% [markdown]
# # Practice Questions
# #### Recursive functions
# #### 1) WAP for factorial computation

# %% [markdown]
# ## Recursive Function

# %%
#Fibonaci sequence

def fibo(n):
    assert n > 0
    if n == 1:
        return 0
    elif n == 2:
        return 1
    else:
        return fibo(n-1) + fibo(n-2)

def main():
    n = int(input("Enter the value of n: "))
    result = fibo(n)
    print(n,'th Fibonacci term','is : ',result)

if __name__ == '__main__':
    main()
# Out:
# Enter the value of n: 7
# 7 th Fibonacci term is :  8

# %% [markdown]
# ### Problems
#
# Reverse the string using recursive function
#
# Palindrom the string

# %% [markdown]
# for loop

# %%
languages = ['R', 'Python',  'Scala', 'Java', 'Julia']
for index in range(len(languages)):
   print('Current language:', languages[index])

# %%
# Print the below statement 3 times
for number in range(3) :
    print("-------------------------------------------")
    print("I am NIRMA Student "+str(number))
    # Inner loop
    for another_number in range(5):
        print("****************************")
        print("I belong to CSE department "+str(another_number))
