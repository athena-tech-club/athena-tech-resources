# %%
    import pandas as pd
import numpy as np
import math
data = pd.read_csv("BostonHousing.csv",header = None).values
x = data[:,0:-1]
y = data[:,-1]
nrows = data.shape[0]
print("Total rows :-",nrows)
test_split = float(input("Enter the split of training between 0 and 1 :- "))
nrows_train = math.floor((1-test_split)*nrows)
all_indices = np.random.permutation(nrows)
print(all_indices)
x_train = x[all_indices[0:nrows_train],:]
y_train = y[all_indices[0:nrows_train]]
x_test = x[all_indices[nrows_train:],:]
y_test = y[all_indices[nrows_train:]]
print("All shapes :- ",x_test.shape,y_test.shape,x_train.shape, y_train.shape)
print("Union :- ", len(set(all_indices[0:nrows_train]).union(all_indices[nrows_train:])))
print("Intersection :- ", len(set(all_indices[0:nrows_train]).intersection(all_indices[nrows_train:])))
# Out:
# Total rows :- 507
# Enter the split of training between 0 and 1 :- 0.2
# [ 65 301 349  47  95 506 306  81 315 317 183 313  92 297 331 468 171  26
#  169 409 170 269 446  25 423 447 400 200 165 287 230  80 356 158 217  86
#   12 251 316 300 254 462 491 445 318 493 111 263  40 484 494 160 264 290
#   21 228   9 320 500 314 258 240 218 358 362 176 110  90 202  13 333 166
#   52 271 203  55 134 105 455 291 136 343   7 490 253 477 245 195 194 277
#  392  71  88 209 133  33  51 425 469 208 188 450 197 222  69 284 114  18
#  408 346 449  70 155 411 365 487 473 441  23 267 429 272 151 235 123  60
#  396 438 463 454 224 505  11 207 492 387 106 154  83 220 172 385 312 406
#  363 426  46 115 132  59 174 196 502 413 122 439 288 137  72 488 338 377
#  371 185 335 206 252  44 140 432 138  77 430 292 189 334 456 375 219 344
#  328 419 394 460 152 386 326 274 192 355 405 279 366  28 367 190 124 332
#  215 486 345 262 127  78 442 130 461 102 330 282  84 404 299 226 266 231
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
data = pd.read_csv("BostonHousing.csv", header = None).values
x = data[:,0:-1]
y = data[:,-1]
nrows = data .shape[0]
print("Total rows = ", nrows)
test_split = float(input("Enter the split of the train between 0 and 1 :-"))
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=test_split)
print("Shapes = ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# Total rows =  507
# Enter the split of the train between 0 and 1 :-0.6
# Shapes =  (202, 13) (305, 13) (202,) (305,)
