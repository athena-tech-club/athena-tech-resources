# %%
# !pip install pypdf
import pypdf

def extract_text_from_pdf(pdf_path):

    pdf_reader = pypdf.PdfReader(pdf_path)


    text = ""


    for page_num in range(len(pdf_reader.pages)):
        page = pdf_reader.pages[page_num]
        text += page.extract_text()

    return text


pdf_path = "coverletter.pdf"


pdf_text = extract_text_from_pdf(pdf_path)


print(pdf_text)
# Out:
# Collecting pypdf
#   Downloading pypdf-4.3.1-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.12.2)
# Downloading pypdf-4.3.1-py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.8/295.8 kB 4.8 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-4.3.1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-d473b6174377> in <cell line: 22>()
#      20
#      21
# ---> 22 pdf_text = extract_text_from_pdf(pdf_path)
#      23
#      24
#
# <ipython-input-2-d473b6174377> in extract_text_from_pdf(pdf_path)
#       4 def extract_text_from_pdf(pdf_path):
#       5
# ----> 6     pdf_reader = pypdf.PdfReader(pdf_path)
#       7
#       8
#
# /usr/local/lib/python3.10/dist-packages/pypdf/_reader.py in __init__(self, stream, strict, password)
#     132         self._stream_opened = False
#     133         if isinstance(stream, (str, Path)):
# --> 134             with open(stream, "rb") as fh:
#     135                 stream = BytesIO(fh.read())
#     136             self._stream_opened = True
#
# FileNotFoundError: [Errno 2] No such file or directory: 'coverletter.pdf'
