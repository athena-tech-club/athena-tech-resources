# %%
import numpy as np
from matplotlib import pyplot as plt

x = np.array([[0,0], [0,1], [1,0], [1,1]])
y = np.array([0,1,1,0])

plt.scatter(x = x[:,0], y = x[:,1], c = y)
plt.show()

n_samples = x.shape[0]
n_features = x.shape[1]
w = np.random.uniform(0,1,size = n_features)
b = np.random.uniform(0,1,1)

n_epoch = int(input("Enter the number of epochs : "))
learning_rate = 0.01

for e in range(n_epoch):
  for s in range(n_samples):
    net = np.dot(x[s,:],w)+b
    if net>=0 :
      a = 1
    else :
      a = 0
    error = y[s] - a
    w = w + learning_rate*error*x[s,:]
    b = b + learning_rate*error

m = -w[0]/w[1]
c = -b/w[1]

def plot_decision_boundary(x):
  m = -w[0]/w[1]
  c = -b/w[1]
  for x in np.linspace(np.min(x[:,0]), np.max(x[:,0])):
    y = m*x + c
    plt.plot(x,y, linestyle = '-', color = 'k', marker = '.')
  plt.scatter(x[:,0],x[:,1], c = y)
  plt.show()

plot_decision_boundary(x)
# Out:
# Enter the number of epochs : 2
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-860df8a2ba9e> in <cell line: 41>()
#      39   plt.show()
#      40
# ---> 41 plot_decision_boundary(x)
#
# <ipython-input-4-860df8a2ba9e> in plot_decision_boundary(x)
#      36     y = m*x + c
#      37     plt.plot(x,y, linestyle = '-', color = 'k', marker = '.')
# ---> 38   plt.scatter(x[:,0],x[:,1], c = y)
#      39   plt.show()
#      40
#
# IndexError: invalid index to scalar variable.
